# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score
import numpy as np

# %%
# Step 1: Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Step 2: Data Preprocessing
# Normalize the data to have values between 0 and 1
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
# Reshape the data to add a channel dimension (required by Conv2D)
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %%
# One-hot encode the target labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
# Step 3: Build a simple Convolutional Neural Network model
model = models.Sequential()

# %%
# Add Convolutional Layer
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Add another Convolutional Layer
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# %%
# Flatten the output
model.add(layers.Flatten())

# %%
# Add a Fully Connected Layer
model.add(layers.Dense(64, activation='relu'))

# %%
# Add the Output Layer
model.add(layers.Dense(10, activation='softmax'))  # 10 classes (digits 0-9)

# %%
# Step 4: Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Step 5: Train the model
history = model.fit(X_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - accuracy: 0.8664 - loss: 0.4581 - val_accuracy: 0.9735 - val_loss: 0.0881
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 79s 55ms/step - accuracy: 0.9805 - loss: 0.0651 - val_accuracy: 0.9789 - val_loss: 0.0677
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.9871 - loss: 0.0423 - val_accuracy: 0.9860 - val_loss: 0.0485
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 40s 54ms/step - accuracy: 0.9906 - loss: 0.0304 - val_accuracy: 0.9885 - val_loss: 0.0407
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 44s 58ms/step - accuracy: 0.9924 - loss: 0.0252 - val_accuracy: 0.9883 - val_loss: 0.0438

# %%
# Step 6: Evaluate the model on the test dataset
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9858 - loss: 0.0438

# %%
# Perform prediction
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step

# %%
# Calculate accuracy
print(f"Test Accuracy: {accuracy_score(y_true, y_pred)}")
# Out:
# Test Accuracy: 0.9885
